# %% [markdown]
# # This script is used to automatically generate datasets formatted to be interpretable by DeepLabCut.
#
# **WARNING :** Restrict the **Colony size** to a **maxmimum of 20 workers**, otherwise the generation of datasets will fail, as the number of necessary columns would exceed the 64kb Metadata limit of the exported HDF5 file!
#
# Ensure, that your **GPU** has sufficient **memory** for the chosen resolution!
#
# E.g. at 1024 px X 1024 px, training on an RTX 2080 Ti, set the **batchsize** to 4 in the **pose_cfg.yaml** file of your model.

# %%
import cv2
import pathlib

import numpy as np
import pandas as pd
import matplotlib as plt

from os import listdir
from os.path import isfile, join

# %%
# define location of dataset and return all files
dataset_location = "J:/FARTS_Project_UE5/Output_DLC_Small_Colony"
target_dir = "I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test_label-Fabi-2021-07-23/labeled-data/multi_animal_synth"
all_files = [f for f in listdir(dataset_location) if isfile(join(dataset_location, f))]

# next, sort files into images, depth maps, segmentation maps, data, and colony info
dataset_img = []
dataset_depth = []
dataset_seg = []
dataset_data = []
dataset_colony = dataset_location + "/ColonieInfo.csv"

for file in all_files:
    loc = dataset_location + "/" + file
    if file[-7:-4] == "Img":
        dataset_img.append(loc)
    elif file[-7:-4] == "Seg":
        dataset_seg.append(loc)
    elif file[-8:-4] == "Depth":
        dataset_depth.append(loc)
    elif file[-8:-4] == "Data":
        dataset_data.append(loc)
        
print("Found",len(all_files),"files...")

# next sort the colony info into its IDs to determine the colony size and individual scales
# one entry for each successive ID is read
from csv import reader

colony = {'seed': 0,
            'ID': [],
         'scale': []}

with open(dataset_colony, 'r') as colony_file:
        print("reading", file)
        # pass the file object to reader() to get the reader object
        csv_reader = reader(colony_file)
        # iterate over each row in the csv using reader object
        for r, row in enumerate(csv_reader):
            if r == 0:
                colony['seed'] = row[0].split("=")[-1]
            else:
                colony['ID'].append(row[0].split("=")[-1])
                colony['scale'].append(row[1].split("=")[-1])

print("Loaded colony file with seed",colony['seed'],"and",len(colony['ID']),"individuals.")
# Out:
# Found 39797 files...
# reading ColonieInfo.csv
# Loaded colony file with seed  0 and 10 individuals.

# %% [markdown]
# Now that we have the cleaned colony info, we can start loading the data associated with each frame.
# For simplicity we will simply make this a list of lists as the number of individuals.
#
# We will therefore access "data" as [frame] [individual] [attribute], where attributes will include [ID,bbox_x_0,bbox_y_0,...]
#
# To train a multi-animal DeepLabCut network, we mostly care about joint positions and less about bounding boxes.

# %%
data = []

for file in dataset_data:
    # store all returned coordinates for each individual
    coords = []
        
    # open file in read mode
    with open(file, 'r') as read_obj:
        print("reading", file)
        # pass the file object to reader() to get the reader object
        csv_reader = reader(read_obj)
        # iterate over each row in the csv using reader object
        for row in csv_reader:
            individual = [float(row[0].split(".")[0])]
            # row variable is a list that represents a row in csv
            for elem in row:
                try:
                    individual.append(float(elem.split("=")[-1]))
                except ValueError:
                    pass
            coords.append(individual)
        
    data.append(coords)
    
print("\nThe dataset has a total of", len(data),"generated frames.")
# Out:
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/10000_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1000_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1001_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1002_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1003_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1004_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1005_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1006_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1007_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1008_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1009_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1010_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1011_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1012_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1013_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1014_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1015_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1016_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1017_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1018_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1019_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/101_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1020_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1021_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1022_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1023_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1024_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1025_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1026_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1027_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1028_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1029_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/102_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/1030_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/
Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9873_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9874_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9875_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9876_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9877_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9878_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9879_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/987_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9880_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9881_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9882_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9883_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9884_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9885_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9886_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9887_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9888_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9889_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/988_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9890_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9891_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9892_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9893_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9894_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9895_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9896_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9897_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9898_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9899_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/989_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/98_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9900_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9901_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9902_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9903_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9904_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9905_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9906_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9907_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9908_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9909_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/990_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9910_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9911_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9912_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9913_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9914_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9915_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9916_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9917_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9918_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9919_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/991_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9920_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9921_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9922_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9923_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9924_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9925_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9926_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9927_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9928_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9929_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/992_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9930_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9931_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9932_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9933_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9934_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9935_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9936_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9937_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9938_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9939_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/993_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9940_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9941_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9942_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9943_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9944_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9945_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9946_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9947_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9948_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9949_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/994_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9950_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9951_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9952_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9953_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9954_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9955_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9956_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9957_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9958_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9959_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/995_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9960_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9961_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9962_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9963_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9964_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9965_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9966_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9967_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9968_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9969_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/996_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9970_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9971_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9972_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9973_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9974_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9975_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9976_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9977_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9978_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9979_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/997_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9980_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9981_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9982_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9983_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9984_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9985_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9986_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9987_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9988_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9989_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/998_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9990_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9991_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9992_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9993_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9994_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9996_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9997_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9998_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9999_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/999_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/99_Data.csv
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9_Data.csv
#
# The dataset has a total of 9949 generated frames.

# %% [markdown]
# As there may be animals for which we don't use all bones we can return a list of all labels and exclude the respective locations from the pose data. As all animals use the same convention, we can simply read in one example and remove the corresponding indices from all animals.

# %%
# first open and read the first line from the first imported data file
labels = []
with open(dataset_data[0], 'r') as read_obj:
    print("reading", file)
    # pass the file object to reader() to get the reader object
    csv_reader = reader(read_obj)
    row_0 = next(csv_reader)  # gets the first line
    # iterate over each row in the csv using reader object
    for elem in row_0:
        try:
            labels.append((elem.split("=")[0].split("Bone.")[-1]))
        except ValueError:
            pass

# now let's define which labels NOT to use (in our case, all labels relating to wings)
omit_labels = ['w_1_r.X', 'w_1_r.Y', 'w_1_r_end.X', 'w_1_r_end.Y', 
               'w_2_r.X', 'w_2_r.Y', 'w_2_r_end.X', 'w_2_r_end.Y',
               'w_1_l.X', 'w_1_l.Y', 'w_1_l_end.X', 'w_1_l_end.Y', 
               'w_2_l.X', 'w_2_l.Y', 'w_2_l_end.X', 'w_2_l_end.Y']

# return indices of labels to be omitted from pose_labels
matched_labels = [i for i, item in enumerate(labels) if item in omit_labels]
print("\nOmitting labels:",omit_labels)
print("\nCorresponding to the following indices:",matched_labels)

"""
# time to remove them from all individuals in "data"
for f, frame in enumerate(data):
    for i, individual in enumerate(frame):
        ind_temp = np.array(data[f][i])
        data[f][i] = np.delete(ind_temp, matched_labels)
"""

# show all used labels:
print("\nAll labels:")
print(labels)
# Out:
# reading J:/FARTS_Project_UE5/Output_DLC_Small_Colony/9_Data.csv
#
# Omitting labels: ['w_1_r.X', 'w_1_r.Y', 'w_1_r_end.X', 'w_1_r_end.Y', 'w_2_r.X', 'w_2_r.Y', 'w_2_r_end.X', 'w_2_r_end.Y', 'w_1_l.X', 'w_1_l.Y', 'w_1_l_end.X', 'w_1_l_end.Y', 'w_2_l.X', 'w_2_l.Y', 'w_2_l_end.X', 'w_2_l_end.Y']
#
# Corresponding to the following indices: [60, 61, 62, 63, 64, 65, 66, 67, 110, 111, 112, 113, 114, 115, 116, 117]
#
# All labels:
# ['1.BoundingBox.BoundMin.X', 'BoundingBox.BoundMin.Y', 'BoundingBox.BoundMax.X', 'BoundingBox.BoundMax.Y', 'b_t.X', 'b_t.Y', 'b_a_1.X', 'b_a_1.Y', 'b_a_2.X', 'b_a_2.Y', 'b_a_3.X', 'b_a_3.Y', 'b_a_4.X', 'b_a_4.Y', 'b_a_5.X', 'b_a_5.Y', 'b_a_5_end.X', 'b_a_5_end.Y', 'l_1_co_r.X', 'l_1_co_r.Y', 'l_1_tr_r.X', 'l_1_tr_r.Y', 'l_1_fe_r.X', 'l_1_fe_r.Y', 'l_1_ti_r.X', 'l_1_ti_r.Y', 'l_1_ta_r.X', 'l_1_ta_r.Y', 'l_1_pt_r.X', 'l_1_pt_r.Y', 'l_1_pt_r_end.X', 'l_1_pt_r_end.Y', 'l_2_co_r.X', 'l_2_co_r.Y', 'l_2_tr_r.X', 'l_2_tr_r.Y', 'l_2_fe_r.X', 'l_2_fe_r.Y', 'l_2_ti_r.X', 'l_2_ti_r.Y', 'l_2_ta_r.X', 'l_2_ta_r.Y', 'l_2_pt_r.X', 'l_2_pt_r.Y', 'l_2_pt_r_end.X', 'l_2_pt_r_end.Y', 'l_3_co_r.X', 'l_3_co_r.Y', 'l_3_tr_r.X', 'l_3_tr_r.Y', 'l_3_fe_r.X', 'l_3_fe_r.Y', 'l_3_ti_r.X', 'l_3_ti_r.Y', 'l_3_ta_r.X', 'l_3_ta_r.Y', 'l_3_pt_r.X', 'l_3_pt_r.Y', 'l_3_pt_r_end.X', 'l_3_pt_r_end.Y', 'w_1_r.X', 'w_1_r.Y', 'w_1_r_end.X', 'w_1_r_end.Y', 'w_2_r.X', 'w_2_r.Y', 'w_2_r_end.X', 'w_2_r_end.Y', 'l_1_co_l.X', 'l_1_co_l.Y', 'l_1_tr_l.X', 'l_1_tr_l.Y', 'l_1_fe_l.X', 'l_1_fe_l.Y', 'l_1_ti_l.X', 'l_1_ti_l.Y', 'l_1_ta_l.X', 'l_1_ta_l.Y', 'l_1_pt_l.X', 'l_1_pt_l.Y', 'l_1_pt_l_end.X', 'l_1_pt_l_end.Y', 'l_2_co_l.X', 'l_2_co_l.Y', 'l_2_tr_l.X', 'l_2_tr_l.Y', 'l_2_fe_l.X', 'l_2_fe_l.Y', 'l_2_ti_l.X', 'l_2_ti_l.Y', 'l_2_ta_l.X', 'l_2_ta_l.Y', 'l_2_pt_l.X', 'l_2_pt_l.Y', 'l_2_pt_l_end.X', 'l_2_pt_l_end.Y', 'l_3_co_l.X', 'l_3_co_l.Y', 'l_3_tr_l.X', 'l_3_tr_l.Y', 'l_3_fe_l.X', 'l_3_fe_l.Y', 'l_3_ti_l.X', 'l_3_ti_l.Y', 'l_3_ta_l.X', 'l_3_ta_l.Y', 'l_3_pt_l.X', 'l_3_pt_l.Y', 'l_3_pt_l_end.X', 'l_3_pt_l_end.Y', 'w_1_l.X', 'w_1_l.Y', 'w_1_l_end.X', 'w_1_l_end.Y', 'w_2_l.X', 'w_2_l.Y', 'w_2_l_end.X', 'w_2_l_end.Y', 'b_h.X', 'b_h.Y', 'ma_r.X', 'ma_r.Y', 'ma_r_end.X', 'ma_r_end.Y', 'an_1_r.X', 'an_1_r.Y', 'an_2_r.X', 'an_2_r.Y', 'an_3_r.X', 'an_3_r.Y', 'an_3_r_end.X', 'an_3_r_end.Y', 'ma_l.X', 'ma_l.Y', 'ma_l_end.X', 'ma_l_end.Y', 'an_1_l.X', 'an_1_l.Y', 'an_2_l.X', 'an_2_l.Y', 'an_3_l.X', 'an_3_l.Y', 'an_3_l_end.X', 'an_3_l_end.Y']

# %% [markdown]
# Now that we have loaded data and colony info we can start plotting bounding boxes on top of their respective images

# %%
# transform between sRGB and linear colour space (optional)

def to_linear(srgb):
    linear = np.float32(srgb) / 255.0
    less = linear <= 0.04045
    linear[less] = linear[less] / 12.92
    linear[~less] = np.power((linear[~less] + 0.055) / 1.055, 2.4)
    return linear * 255.0

    
def from_linear(linear):
    srgb = linear.copy()
    less = linear <= 0.0031308
    srgb[less] = linear[less] * 12.92
    srgb[~less] = 1.055 * np.power(linear[~less], 1.0 / 2.4) - 0.055
    return srgb * 255.0

# %%
# let's create a big dictionary to store all our dataset info and
# save it all to the desired .csv and .h5 files for DeepLabCut to read.

all_points = np.empty((len(data), (len(colony['ID'])*(len(labels) - len(matched_labels) -4))))
#	- scorer   #(just one, the only scorer is the generator)
#	- - individuals
#	- - - bodyparts
#	- - - - coords

print("Number of loaded samples:",len(data))
print("Colony size:",len(colony['ID']))
print("body parts:",int(((len(labels)-4) - len(matched_labels))/2)," (including X & Y coordinates)\n")
print("Resulting in an array of shape:",all_points.shape)

output_file_names = ["" for i in range(len(data))]
# Out:
# Number of loaded samples: 9949
# Colony size: 10
# body parts: 62  (including X & Y coordinates)
#
# Resulting in an array of shape: (9949, 1240)

# %%
# create unique colours for each ID
import numpy as np
import time

# alright. Let's take it from the top and fucking multi-thread this.
import threading
import queue
import sys
import os

def getThreads():
    """ Returns the number of available threads on a posix/win based system """
    if sys.platform == 'win32':
        return int(os.environ['NUMBER_OF_PROCESSORS'])
    else:
        return int(os.popen('grep -c cores /proc/cpuinfo').read())

class exportThread(threading.Thread):
    def __init__(self, threadID, name, q):
        threading.Thread.__init__(self)
        self.threadID = threadID
        self.name = name
        self.q = q

    def run(self):
        print("Starting " + self.name)
        process_detections(self.name, self.q)
        print("Exiting " + self.name)
        
def createThreadList(num_threads):
    threadNames = []
    for t in range(num_threads):
        threadNames.append("Thread_" + str(t))

    return threadNames

def process_detections(threadName, q):
    while not exitFlag_export:
        queueLock.acquire()
        if not workQueue_export.empty():
            
            data_input = q.get()
            i = data_input[0]
            img = data_input[1]
            queueLock.release()
            
            display_img = cv2.imread(img)
            display_img_orig = display_img.copy()
            
            img_shape = display_img.shape
            
            # only add images that contain visibile individuals
            is_empty = True
            
            img_name = target_dir + "/" + img.split('/')[-1][:-4] + "_synth" + ".png"
            # write the file path to the all_points array
            output_file_names[i] = img_name

            img_info = []
                
            # compute visibility for each individual
            seg_img = cv2.imread(dataset_seg[i])
            seg_img_display = seg_img.copy()

            for im, individual in enumerate(data[i]):

                fontColor = (int(ID_colours[int(individual[0]),0]),
                             int(ID_colours[int(individual[0]),1]),
                             int(ID_colours[int(individual[0]),2]))
                bbox = fix_bounding_boxes(individual[1:5],max_val=display_img.shape)
                    
                # FOR SOME REASON OCCASIONALLY THE ID OF THE SEG FILE IS LOWER THAN THE DATA FILE
                # with: ID = red_channel/255 * im
                # red_channel = (ID/im) * 255
                ID_red_val = int((individual[0]/len(colony['ID']))*255)
                
                try:
                    ID_mask = cv2.inRange(seg_img[bbox[1]:bbox[3],bbox[0]:bbox[2]], np.array([0,0, ID_red_val - 2]), np.array([0,0, ID_red_val + 2]))
                    indivual_occupancy = cv2.countNonZero(ID_mask)
                except:
                    indivual_occupancy = 1

                #indivual_occupancy = np.count_nonzero((seg_img == [0, 0, int((individual[0]/len(colony['ID']))*255)]).all(axis = 2)) + np.count_nonzero((seg_img == [0, 0, int((individual[0]/len(colony['ID']))*255 - 1)]).all(axis = 2)) + np.count_nonzero((seg_img == [0, 0, int((individual[0]/len(colony['ID']))*255 + 1)]).all(axis = 2))
                bbox_area = abs((bbox[2] - bbox[0]) * (bbox[3] - bbox[1])) + 1
                bbox_occupancy = indivual_occupancy / bbox_area
                #print("Individual", individual[0], "with bounding box occupancy ",bbox_occupancy)

                #cv2.putText(display_img, "ID: " + str(int(individual[0])), (bbox[0] + 10,bbox[3] - 10), font, fontScale, fontColor, lineType)
                if bbox_occupancy > visibility_threshold:
                    #cv2.rectangle(display_img, (bbox[0], bbox[1]), (bbox[2], bbox[3]), fontColor, 2)
                     
                    output_cell = 0    
                    for point in range(int(len(individual[5:])/2)):
                        # get rid of all invalid points first. Those should simply stay NaN in the array
                        if point*2 + 4 in matched_labels:
                            pass
                        elif individual[point*2 + 5] > img_shape[0] or individual[point*2 + 5] < 0 or individual[point*2 + 6] > img_shape[1] or individual[point*2 + 6] < 0:
                            output_cell += 1
                        else:
                            # now throw the coordinates to the correct location
                            out_row = i
                            out_column = int(individual[0]) * (int(len(labels) - len(matched_labels) - 4)) + output_cell * 2 
                            all_points[out_row][out_column] = individual[point*2 + 5] # X
                            all_points[out_row][out_column + 1] = individual[point*2 + 6] # Y
                        
                            output_cell += 1
                   
            cv2.imwrite(img_name, display_img)
            
        else:
            queueLock.release()
            
# setup as many threads as there are (virtual) CPU cores
exitFlag_export = 0
# only use a fourth of the number of CPUs for export as hugin and enfuse utilise multi core processing in part
threadList_export = createThreadList(getThreads())
print("Using", len(threadList_export), "threads for export...")
queueLock = threading.Lock()

# define paths to all images and set the maximum number of items in the queue equivalent to the number of images
workQueue_export = queue.Queue(len(dataset_img))
threads = []
threadID = 1

np.random.seed(seed=1)
ID_colours = np.random.randint(255, size=(len(colony['ID']), 3))

font = cv2.FONT_HERSHEY_SIMPLEX
fontScale = 0.5
lineType = 2

# we can additionally plot the points in the data files to check joint locations
plot_joints = True

# remember to refine an export folder when saving out your dataset
generate_dataset = True

def fix_bounding_boxes(coords,max_val = [1024,1024]):
    # fix bounding box coordinates so they do not reach beyond the image
    fixed_coords = []
    for c, coord in enumerate(coords):
        if c == 0 or c == 2:
            max_val_temp = max_val[0]
        else:
            max_val_temp = max_val[1]
            
        if coord >= max_val_temp:
            coord = max_val_temp
        elif coord <= 0:
            coord = 0
        
        fixed_coords.append(int(coord))
        
    return fixed_coords

# determine the proportion of a bounding box that needs to be filled before considering the visibility as too low
# WARNING: At the moment the ID shown in segmentation maps does not always correspond to the ID in the data file (off by 1)
visibility_threshold = 0.015

timer = time.time()

# Create new threads
for tName in threadList_export:
    thread = exportThread(threadID, tName, workQueue_export)
    thread.start()
    threads.append(thread)
    threadID += 1

# Fill the queue with stacks
queueLock.acquire()
for i,img in enumerate(dataset_img):
    workQueue_export.put([i, img])
queueLock.release()

# Wait for queue to empty
while not workQueue_export.empty():
    pass

# Notify threads it's time to exit
exitFlag_export = 1

# Wait for all threads to complete
for t in threads:
    t.join()
print("Exiting Main export Thread")

# close all windows if they were opened
cv2.destroyAllWindows()

print("Total time elapsed:",time.time()-timer,"seconds")
# Out:
# Using 28 threads for export...
# Starting Thread_0
# Starting Thread_1
# Starting Thread_2
# Starting Thread_3
# Starting Thread_4
# Starting Thread_5
# Starting Thread_6
# Starting Thread_7
# Starting Thread_8
# Starting Thread_9
# Starting Thread_10
# Starting Thread_11
# Starting Thread_12
# Starting Thread_13
# Starting Thread_14
# Starting Thread_15
# Starting Thread_16
# Starting Thread_17
# Starting Thread_18
# Starting Thread_19
# Starting Thread_20
# Starting Thread_21
# Starting Thread_22
# Starting Thread_23
# Starting Thread_24
# Starting Thread_25
# Starting Thread_26
# Starting Thread_27
# Exiting Thread_8Exiting Thread_11
#
# Exiting Thread_16
# Exiting Thread_18
# Exiting Thread_15Exiting Thread_1Exiting Thread_3
#
#
# Exiting Thread_0
# Exiting Thread_22Exiting Thread_17Exiting Thread_21Exiting Thread_4Exiting Thread_7
#
#
#
#
# Exiting Thread_9
# Exiting Thread_24
# Exiting Thread_6Exiting Thread_19
#
# Exiting Thread_2Exiting Thread_27Exiting Thread_14Exiting Thread_23
#
#
# Exiting Thread_20
# Exiting Thread_26
# Exiting Thread_10
# Exiting Thread_5Exiting Thread_13
#
#
# Exiting Thread_12
# Exiting Thread_25
# Exiting Main export Thread
# Total time elapsed: 132.4639914035797 seconds

# %% [markdown]
# Now, dump it all into one **DLC-conform pandas (.h5)** file

# %%
#example_DLC_df = pd.read_hdf("I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test_label-Fabi-2021-07-23/labeled-data/multi_animal_1080p/CollectedData_Fabi.h5")
#print(example_DLC_df.columns.get_level_values(2))
#example_DLC_df

# %%
# low let's create the required hierarchy
scorer = ["FARTS" for i in range(len(all_points[0]))]
individuals = []

for ind in range(len(colony['ID'])):
    individual = ["ant_" + str(ind) for i in range(int((len(labels)-4) - len(matched_labels)))]
    individuals.extend(individual)
    
bodyparts_filtered = [item.split(".")[0] for item in labels if item not in omit_labels][4:]
bodyparts = []

for i in range(len(colony['ID'])):
    bodyparts.extend(bodyparts_filtered)
    
coords = []
for i in range(int(len(all_points[0])/2)):
    coords.extend(["x","y"])

# %% [markdown]
# Now that all elemts for the **Multi-Index** hierachy are defined, we can combine them into the **final dataframe**

# %%
categories = [scorer, individuals, bodyparts, coords]
categories_tuples = list(zip(*categories))
columns = pd.MultiIndex.from_tuples(categories_tuples, names=["scorer",
                                                           "individuals",
                                                           "bodyparts",
                                                           "coords"])

final_dataframe = pd.DataFrame(all_points, index = output_file_names, columns=columns)
# convert all zeros to NaN
final_dataframe = final_dataframe.replace(0, np.nan)

# %%
final_dataframe
# Out:
# scorer                                                   FARTS              \
# individuals                                              ant_0
# bodyparts                                                  b_t
# coords                                                       x           y
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  503.478638  455.677094
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  255.091217  663.576172
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  507.146667  457.729156
# ...                                                        ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  179.106934  721.512085
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  740.427673  671.349670
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  435.196075  707.773193
#
# scorer                                                                      \
# individuals
# bodyparts                                                b_a_1
# coords                                                       x           y
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  519.438782  483.382477
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  171.478638  623.629028
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  492.001373  482.107605
# ...                                                        ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  224.474304  681.957031
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  782.162109  655.815430
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  354.095062  659.906250
#
# scorer                                                                      \
# individuals
# bodyparts                                                b_a_2
# coords                                                       x           y
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  522.862122  488.461029
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  155.415924  617.830261
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  490.207550  487.448792
# ...                                                        ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  235.849762  672.742004
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  791.741943  651.280518
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  338.166748  647.794739
#
# scorer                                                                      \
# individuals
# bodyparts                                                b_a_3
# coords                                                       x           y
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  524.526550  491.760773
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  146.675934  612.945007
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  489.528961  490.744843
# ...                                                        ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  243.947052  664.530029
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  800.102417  647.148071
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  329.589111  637.172241
#
# scorer                                                                      \
# individuals
# bodyparts                                                b_a_4
# coords                                                       x           y
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  519.127014  495.457153
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  151.049255  621.642395
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  490.809143  488.379944
# ...                                                        ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  241.528442  662.162598
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  808.012207  644.911194
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  324.958496  637.308472
#
# scorer                                              ...              \
# individuals                                         ...       ant_9
# bodyparts                                           ...    ma_l_end
# coords                                              ...           x
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...  254.686218
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...  444.326355
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...         NaN
# ...                                                 ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...  426.002136
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  ...  494.434723
#
# scorer                                                                      \
# individuals
# bodyparts                                                           an_1_l
# coords                                                       y           x
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  195.157837  255.316650
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  533.026428  468.570526
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# ...                                                        ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  505.986572  437.179626
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  460.664886  504.653992
#
# scorer                                                                      \
# individuals
# bodyparts                                                           an_2_l
# coords                                                       y           x
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  205.248444  258.210999
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  538.838806  496.454895
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# ...                                                        ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  525.172791  457.635132
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  487.287720  532.031860
#
# scorer                                                                      \
# individuals
# bodyparts                                                           an_3_l
# coords                                                       y           x
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  215.014374  248.897888
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  527.129822  500.708435
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# ...                                                        ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  526.156006  459.746643
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  504.421692  517.909363
#
# scorer                                                                      \
# individuals
# bodyparts                                                       an_3_l_end
# coords                                                       y           x
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  215.318207  244.479370
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  545.458496  505.549133
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# ...                                                        ...         ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  519.212463  466.387848
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  517.687073  518.871033
#
# scorer
# individuals
# bodyparts
# coords                                                       y
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  215.528168
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  547.033081
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN
# ...                                                        ...
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  505.393280
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...         NaN
# I:/FARTS/DeepLabCut-Multi-Animal/multi_ant_test...  520.852112
#
# [9949 rows x 1240 columns]

# %%
final_dataframe.to_csv(os.path.join(target_dir, "CollectedData_FARTS.csv"))

# IF the function below fails, this is likely due to exceeding the number of columns supported by HDF5 files!
# Restrict the number of simulated animals to < 20 if the goal is to train a DLC network

final_dataframe.to_hdf(
    os.path.join(target_dir, "CollectedData_" + "FARTS" + ".h5"),
    "df_with_missing",
    format="table",
    mode="w")
