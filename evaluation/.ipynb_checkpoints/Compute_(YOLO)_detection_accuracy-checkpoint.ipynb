# %% [markdown]
# # Compute (YOLO) detection accuracy
# First, we'll import the ground truth video and blender tracked file

# %%
import numpy as np
import cv2
import csv
import os
import math
import time
import random
import sys
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from operator import itemgetter

# now for the file management fucntions
from Antrax_base import import_tracks, display_video, get_exact_frame, extractPatches, display_patches, sortByDistance

export_paths = ["C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/benchmark/sub_colony_tracking/SAVA/export_handheld_SAVA/"] # add more paths here, if desired
video = "C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/benchmark/sub_colony_tracking/rec_outside_foraging_handheld_plain_450_frames.mp4"

# enter the number of annotated frames:
tracked_frames = 449

# now we can load the captured video file and display it
cap = cv2.VideoCapture(video)

# check the number of frames of the imported video file
numFramesMax = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print("The imported clip:", video, "has a total of",numFramesMax ,"frames.\n")

# now let's load all tracks listed in the export_paths
tracks = []

try:
    for folder in export_paths:
        # You can export all tracks into a single .csv file by setting "export=True"
        tracks.append(import_tracks(folder, numFramesMax, export=False))

        # The following function is used to display the tracks you imported.
        # You can press "q" while hovering over the displayed video to exit.
        print("\nDisplaying tracks loaded from:", folder)
        display_video(cap, tracks[-1], show=(0, tracked_frames), scale=0.3)# scale=1, output_file="C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/benchmark/sub_colony_tracking/RESULTS/" + video[:-4].split("/")[-1] +'_annotations.avi')
except IndexError:
    print("WARNING: Issue importing tracks. Ensure correct numbers of frames are given")
"""
def import_ground_truth(path):
    tracks = np.loadtxt(path, delimiter=",")
    tracks = tracks.astype(int)
    
    print("Imported tracks successfully from", path)
    
    return tracks

tracks.append(import_ground_truth(path="J:/tracking_validation/export_base_NAT/_all_tracks.csv"))
"""
# Out:
# The imported clip: C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/benchmark/sub_colony_tracking/rec_outside_foraging_handheld_plain_450_frames.mp4 has a total of 451 frames.
#
# importing tracks...
# imported rec_outside_foraging_handheld_plain_450_frames_Track.001.csv  with 43 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.002.csv  with 73 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.003.csv  with 98 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.004.csv  with 99 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.005.csv  with 35 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.006.csv  with 47 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.007.csv  with 48 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.008.csv  with 43 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.009.csv  with 83 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.010.csv  with 93 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.011.csv  with 94 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.012.csv  with 67 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.013.csv  with 106 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.014.csv  with 93 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.015.csv  with 57 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.016.csv  with 88 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.017.csv  with 104 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.018.csv  with 93 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.019.csv  with 38 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.020.csv  with 19 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.021.csv  with 35 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.022.csv  with 57 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.023.csv  with 38 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.024.csv  with 21 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.025.csv  with 95 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.026.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.027.csv  with 77 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.028.csv  with 75 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.029.csv  with 66 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.030.csv  with 72 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.031.csv  with 73 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.032.csv  with 76 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.033.csv  with 155 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.034.csv  with 156 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.035.csv  with 157 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.036.csv  with 8 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.037.csv  with 11 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.038.csv  with 9 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.039.csv  with 20 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.040.csv  with 29 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.041.csv  with 5 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.042.csv  with 13 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.043.csv  with 9 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.044.csv  with 93 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.045.csv  with 148 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.046.csv  with 157 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.047.csv  with 134 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.048.csv  with 156 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.049.csv  with 131 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.050.csv  with 92 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.051.csv  with 151 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.052.csv  with 151 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.053.csv  with 153 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.054.csv  with 69 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.055.csv  with 126 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.056.csv  with 141 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.057.csv  with 139 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.058.csv  with 110 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.059.csv  with 42 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.060.csv  with 119 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.061.csv  with 98 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.062.csv  with 139 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.063.csv  with 117 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.064.csv  with 137 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.065.csv  with 133 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.066.csv  with 140 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.067.csv  with 28 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.068.csv  with 139 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.069.csv  with 133 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.070.csv  with 70 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.071.csv  with 133 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.072.csv  with 138 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.073.csv  with 94 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.074.csv  with 139 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.075.csv  with 14 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.076.csv  with 123 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.077.csv  with 118 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.078.csv  with 77 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.079.csv  with 114 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.080.csv  with 128 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.081.csv  with 140 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.082.csv  with 40 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.083.csv  with 87 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.084.csv  with 109 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.085.csv  with 89 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.086.csv  with 112 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.087.csv  with 55 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.088.csv  with 123 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.089.csv  with 33 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.090.csv  with 85 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.091.csv  with 45 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.092.csv  with 91 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.093.csv  with 35 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.094.csv  with 45 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.095.csv  with 73 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.096.csv  with 81 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.097.csv  with 64 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.098.csv  with 20 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.099.csv  with 62 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.100.csv  with 16 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.101.csv  with 21 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.102.csv  with 79 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.103.csv  with 67 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.104.csv  with 66 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.105.csv  with 82 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.106.csv  with 12 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.107.csv  with 64 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.108.csv  with 69 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.109.csv  with 63 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.110.csv  with 34 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.111.csv  with 17 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.112.csv  with 62 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.113.csv  with 64 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.114.csv  with 58 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.115.csv  with 84 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.116.csv  with 76 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.117.csv  with 73 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.118.csv  with 60 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.119.csv  with 56 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.120.csv  with 52 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.121.csv  with 46 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.122.csv  with 53 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.123.csv  with 56 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.124.csv  with 115 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.125.csv  with 72 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.126.csv  with 53 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.127.csv  with 58 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.128.csv  with 56 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.129.csv  with 44 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.130.csv  with 42 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.131.csv  with 56 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.132.csv  with 47 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.133.csv  with 115 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.134.csv  with 47 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.135.csv  with 53 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.136.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.137.csv  with 16 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.138.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.139.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.140.csv  with 41 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.141.csv  with 33 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.142.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.143.csv  with 30 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.144.csv  with 29 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.145.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.146.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.147.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.148.csv  with 39 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.149.csv  with 35 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.150.csv  with 29 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.151.csv  with 31 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.152.csv  with 29 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.153.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.154.csv  with 27 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.155.csv  with 31 points.
# imported rec_outside_foraging_handheld_plain_450_frames_Track.csv  with 70 points.
#
# Successfully combined the tracks of 156 individuals for training and display!
#
# Displaying tracks loaded from: C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/benchmark/sub_colony_tracking/SAVA/export_handheld_SAVA/
#
# Displaying tracked footage!
# press 'q' to end display
# C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/benchmark/sub_colony_tracking/RESULTS/rec_outside_foraging_handheld_plain_450_frames_annotations.avi 1196444237 30.0 (1920, 1080)
# Reached last frame of specified video or ended by user input.
# '\ndef import_ground_truth(path):\n    tracks = np.loadtxt(path, delimiter=",")\n    tracks = tracks.astype(int)\n    \n    print("Imported tracks successfully from", path)\n    \n    return tracks\n\ntracks.append(import_ground_truth(path="J:/tracking_validation/export_base_NAT/_all_tracks.csv"))\n'

# %% [markdown]
# Next, we load our trained network and run inference on the loaded video

# %%
# load darknet with compiled DLLs for windows from respective path
import sys
sys.path.append('C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/build/darknet/x64/')
# load weights trained on synthetic data only
sys.path.append('C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/YOLO/atta_single_class/')
# load weights trained on real data only
#sys.path.append('I:\\FARTS\\trained_YOLO_networks\\real_only_multi_class')
import darknet
import imutils

def nonMaximumSupression(detections):
    """
    :param detections: detections returned from darknet
    :return: only detection of highest confidence. Return None, if no individual was detected
    """
    if len(detections) != 0:
        det_sorted = sorted(detections, key=itemgetter(2))
        max_conf_detection = det_sorted[0][0]
    else:
        max_conf_detection = 'No Detect'
    return max_conf_detection

# load configuration and weights (synthetic)
yolo_cfg = 'C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/YOLO/atta_single_class/yolov4-big_and_small_ants_640.cfg'
yolo_weights = 'C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/YOLO/atta_single_class/yolov4-big_and_small_ants_1024px_refined_with_2048_px_27000.weights'
yolo_data = 'C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/YOLO/atta_single_class/obj.data'
yolo_names = 'C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/YOLO/atta_single_class/obj.names'

# load configuration and weights (real)
#yolo_cfg = 'I:/FARTS/trained_YOLO_networks/real_only_multi_class/yolov4_ant_weight_testing.cfg'
#yolo_weights = 'I:/FARTS/trained_YOLO_networks/real_only_multi_class/yolov4_ant_weight_24000.weights'
#yolo_data = 'I:/FARTS/trained_YOLO_networks/real_only_multi_class/data/obj.data'
#yolo_names = 'I:/FARTS/trained_YOLO_networks/real_only_multi_class/data/obj.names'

from ctypes import *
import math
import random
import os
import cv2
import numpy as np
import time
import darknet

def convertBack(x, y, w, h):
    xmin = int(round(x - (w / 2)))
    xmax = int(round(x + (w / 2)))
    ymin = int(round(y - (h / 2)))
    ymax = int(round(y + (h / 2)))
    return xmin, ymin, xmax, ymax


def cvDrawBoxes(detections, img, min_size=20, constant_size=False):
    for detection in detections:

        x, y, w, h = detection[2][0],\
            detection[2][1],\
            detection[2][2],\
            detection[2][3]
        
        if w >= min_size and h  >= min_size:
            
            if constant_size:
                w, h = constant_size, constant_size

            xmin, ymin, xmax, ymax = convertBack(
                float(x), float(y), float(w), float(h))
            pt1 = (xmin, ymin)
            pt2 = (xmax, ymax)
            cv2.rectangle(img, pt1, pt2, (150, 0, 160), 1)
            cv2.putText(img,
                        detection[0].decode() +
                        " [" + str(round(detection[1] * 100, 2)) + "]",
                        (pt1[0], pt1[1] - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.3,
                        [150, 0, 160], 2)
    return img


netMain = None
metaMain = None
altNames = None

configPath = yolo_cfg
weightPath = yolo_weights
metaPath = yolo_data

if not os.path.exists(configPath):
    raise ValueError("Invalid config path `" +
                     os.path.abspath(configPath)+"`")
if not os.path.exists(weightPath):
    raise ValueError("Invalid weight path `" +
                     os.path.abspath(weightPath)+"`")
if not os.path.exists(metaPath):
    raise ValueError("Invalid data file path `" +
                     os.path.abspath(metaPath)+"`")
if netMain is None:
    netMain = darknet.load_net_custom(configPath.encode(
        "ascii"), weightPath.encode("ascii"), 0, 1)  # batch size = 1
if metaMain is None:
    metaMain = darknet.load_meta(metaPath.encode("ascii"))
if altNames is None:
    try:
        with open(metaPath) as metaFH:
            metaContents = metaFH.read()
            import re
            match = re.search("names *= *(.*)$", metaContents,
                              re.IGNORECASE | re.MULTILINE)
            if match:
                result = match.group(1)
            else:
                result = None
            try:
                if os.path.exists(result):
                    with open(result) as namesFH:
                        namesList = namesFH.read().strip().split("\n")
                        altNames = [x.strip() for x in namesList]
            except TypeError:
                pass
    except Exception:
        pass
# cap = cv2.VideoCapture(0)

print("Starting the YOLO loop...")

# Create an image we reuse for each detect
darknet_image = darknet.make_image(darknet.network_width(netMain),
                                darknet.network_height(netMain),3)

all_detection_centres = []

frame_counter = 0

fourcc = cv2.VideoWriter_fourcc(*'MJPG')
out = cv2.VideoWriter(video[:-4].split("/")[-1]+'_detections.avi', fourcc, 20.0, (darknet.network_width(netMain),darknet.network_height(netMain)))

def scale_detections(x,y,network_w,network_h,output_w,output_h):
    scaled_x = x * (output_w / network_w)
    scaled_y = (network_h - y) * (output_h / network_h) # y is inverted
    return [scaled_x, scaled_y]

start_time = time.time()
while True:
    if frame_counter == tracked_frames: 
        break
        
    prev_time = time.time()
    ret, frame_read = cap.read()
    frame_rgb = cv2.cvtColor(frame_read, cv2.COLOR_BGR2RGB)
    frame_resized = cv2.resize(frame_rgb,
                               (darknet.network_width(netMain),
                                darknet.network_height(netMain)),
                               interpolation=cv2.INTER_LINEAR)

    darknet.copy_image_from_bytes(darknet_image,frame_resized.tobytes())
    
    # thresh : detection threshold -> lower = more sensitive
    # nms : non maximum suppression -> higher = allow for closer proximity between detections
    detections = darknet.detect_image(netMain, metaMain, darknet_image, thresh=0.45, nms=0.55)
    print("Frame:",frame_counter + 1)
    min_size = 25 # minimum size for rerturned detecions
    viable_detections = []
    
    for detection in detections:
        if detection[2][2] >= min_size and detection[2][3] >= min_size:
            # we need to scale the detections to the original imagesize, as they are downsampled above
            scaled_xy = scale_detections(x=detection[2][0], y=detection[2][1],
                                         network_w=darknet.network_width(netMain), network_h=darknet.network_height(netMain),
                                         output_w=frame_rgb.shape[1],output_h=frame_rgb.shape[0])
            viable_detections.append(scaled_xy)
            
    all_detection_centres.append(viable_detections)
        
    image = cvDrawBoxes(detections, frame_resized, min_size=min_size, constant_size=50)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # print(1/(time.time()-prev_time))
    out.write(image)
    cv2.imshow('Detections on video', image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
    frame_counter += 1
    
print("Time elapsed",time.time()-start_time)
print("FPS:", frame_counter / (time.time()-start_time))
cv2.destroyAllWindows()
# always reset frame from capture at the end to avoid incorrect skips during access
cap.set(1, 0)
out.release()
# Out:
# Starting the YOLO loop...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5d0284bb710> in <module>
#     131
#     132 fourcc = cv2.VideoWriter_fourcc(*'MJPG')
# --> 133 out = cv2.VideoWriter(video[:-4].split("/")[-1]+'_detections.avi', fourcc, 20.0, (darknet.network_width(netMain),darknet.network_height(netMain)))
#     134
#     135 def scale_detections(x,y,network_w,network_h,output_w,output_h):
#
# NameError: name 'video' is not defined

# %% [markdown]
# Now, to **compare the detections** to the **ground truth** of each frame, we need to compare every detection to every ground truth instance. This may be computationally expensive, but it ensures all detections are considered. The process can be easiliy multi threaded if desired as each frame is compared independently of the others

# %%
print("Processed frames:",len(all_detection_centres))
from scipy.spatial import distance

max_detection_distance_px = 50# only detections closer than X px away from the centre of a ground truth track are considered correct detections

total_gt_detections = 0 # number of total detections in the ground truth dataset
total_missed_detections = 0 # number of missed detections which are present in the groud truth dataset
total_false_positives = 0 # number of incorrect detections that do not match any groud thruth tracks
all_frame_detection_deviations = [] # list of mean pixel deviations for correct detections

def compare_points(gt,detection, max_dist=25):
    match = False
    px_distance = distance.euclidean(gt, detection)
    if px_distance <= max_dist:
        match = True
    return match, px_distance

def compare_frame(frame_gt, frame_detections, max_dist=50):
    gt_detections = int((np.count_nonzero(frame_gt!=0) - 1) / 2)
    matches_gt = np.ones(gt_detections)
    matches_det = np.ones(len(frame_detections))
    detection_distances = []
    # now strip all empty entries from the ground truth
    frame_gt = frame_gt[frame_gt != 0]
    for i in range(len(matches_gt)):
        min_dist = 9999
        for j in range(len(matches_det)):
            match, px_dist = compare_points(gt=frame_gt[(i*2)+1:(i*2)+3], detection=frame_detections[j], max_dist=max_dist)
            if match:
                matches_gt[i] = 0
                matches_det[j] = 0
                if px_dist < min_dist:
                    min_dist = px_dist
        if min_dist < 9999:
            detection_distances.append(min_dist)
            
    missed_detections = int(np.sum(matches_gt))
    false_positives = int(np.sum(matches_det))
    if len(detection_distances) == 0:
        mean_detection_distance = 0
    else:
        mean_detection_distance = np.mean(np.array(detection_distances))
    
    return gt_detections, missed_detections, false_positives, mean_detection_distance

for f, detections in enumerate(all_detection_centres):
    gt_detections, missed_detections, false_positives, mean_detection_distance = compare_frame(frame_gt=tracks[0][f], frame_detections=detections, max_dist=max_detection_distance_px)
    total_gt_detections += gt_detections
    total_missed_detections += missed_detections
    total_false_positives += false_positives
    all_frame_detection_deviations.append(mean_detection_distance)
    
mean_px_error = np.mean(all_frame_detection_deviations)
detection_accuracy = ((total_gt_detections - total_missed_detections - total_false_positives) / total_gt_detections) * 100
    
print("Total ground truth detections:",total_gt_detections)
print("Total missed detections:",total_missed_detections)
print("Total false positives:",total_false_positives)
print("Detection accuracy (GT - FP - MD) / GT):", np.round(detection_accuracy, 1),"%")
print("Mean pixel error:", np.round(mean_px_error,3))

# %%
# combine all detections into a single 2D array to produce a simple scatter plot
all_xy = []
for frame in all_detection_centres:
    for detection in frame:
        all_xy.append(detection)
        
all_xy = np.array(all_xy)
all_xy = np.reshape(all_xy, (-1,2)) # ensures the format can be read by matplotlib

plt.scatter(all_xy[:,0],all_xy[:,1],s=0.1)
plt.title("Detections")    
plt.xlabel("X axis [px]")   
plt.ylabel("Y axis [px]")
plt.xlim(0,frame_rgb.shape[1])
plt.ylim(0,frame_rgb.shape[0])
plt.savefig("C:/Users/Legos/Documents/PhD/Blender/OmniTrax/OmniTrax_WIP/benchmark/sub_colony_tracking/RESULTS/" + video[:-4].split("/")[-1] + "_" + 
            yolo_cfg.split("_")[-1][:-4] +'_detections.svg')
plt.show()
